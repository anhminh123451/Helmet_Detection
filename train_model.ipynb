# %%
# !uv pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.16 🚀 Python-3.12.12 torch-2.10.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 21.3/107.7 GB disk)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="AAuzrzhbPnGHKwSbyw3j")
project = rf.workspace("helmetdetection-cu2fa").project("helmet-jwrns")
version = project.version(1)
dataset = version.download("yolo26")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="AAuzrzhbPnGHKwSbyw3j")
project = rf.workspace("lakshmi-yekkanti").project("helmet-detection-wczch")
version = project.version(1)
dataset = version.download("yolo26")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Helmet-Detection-1 in yolo26:: 100%|██████████| 1270/1270 [00:00<00:00, 8831.65it/s]

# %%
# !yolo train model=yolo26n.pt data=/content/Helmet-1/data.yaml epochs=100 imgsz=640
# Out:
# ...
# Ultralytics 8.4.16 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !yolo train model=/content/checkpoint_yolo.pt data=/content/Helmet-Detection-1/data.yaml epochs=100 imgsz=640
# Out:
# Ultralytics 8.4.16 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO('/content/checkpoint.pt')

results = model('/content/helmet.png')
# Out:
# image 1/1 /content/helmet.png: 480x640 2 With Helmets, 535.3ms
# Speed: 16.5ms preprocess, 535.3ms inference, 5.4ms postprocess per image at shape (1, 3, 480, 640)

# %%
results[0].show()
# Out:
# <PIL.Image.Image image mode=RGB size=466x347>

# %%
# !yolo predict model=/content/runs/detect/train2/weights/best.pt source='/content/Helmet-Detection-1/test/images/BikesHelmets431_png.rf.387c18b991b654dce9843871a2225d38.jpg'
# Out:
# Ultralytics 8.4.16 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO26n summary (fused): 122 layers, 2,375,226 parameters, 0 gradients, 5.2 GFLOPs
#
# image 1/1 /content/Helmet-Detection-1/test/images/BikesHelmets431_png.rf.387c18b991b654dce9843871a2225d38.jpg: 640x640 1 Without Helmet, 16.6ms
# Speed: 4.9ms preprocess, 16.6ms inference, 23.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/detect/predict7
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
